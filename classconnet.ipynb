# %%
import networkx as nx
import matplotlib.pyplot as plt
G = nx.Graph()

# %%
H=(["Baurice","Roaa","Mahad","Cyrille","Rose","Nadine","Samson","Agnes","Mano","Adrien","Nasser","Jodelle",
                  "Sirianne","Caleb","Richmond","Germaine","Younous","Victoire","Ayao","Patience","Olusegun","Romaric",
                  "Raissa","Majeed","Loyce","Josephine","Blessing","Comfort","George","Seun","Rodrigue","Rehema",
                  "Opeyemi","Frank","Dave","Donatien","Janvier","Christian","Jafar","Hans", "Abdul","Laura","Nehemie"])

# %%
len(H)
# Out:
# 43

# %%
G.add_nodes_from(H)

# %%
G.add_nodes_from(["Baurice","Roaa","Mahad","Cyrille","Rose","Nadine","Samson","Agnes","Mano","Adrien","Nasser","Jodelle",
                  "Sirianne","Caleb","Richmond","Germaine","Younous","Victoire","Ayao","Patience","Olusegun","Romaric",
                  "Raissa","Majeed","Loyce","Josephine","Blessing","Comfort","George","Seun","Rodrigue","Rehema",
                  "Opeyemi","Frank","Dave","Donatien","Janvier","Christian","Jafar","Hans", "Abdul","Laura","Nehemie"])

# %%
G.add_edges_from([("Baurice","Raissa"), ("Baurice","Adrien"), ("Roaa","Mahad"),("Roaa","Frank"),("Mahad","Roaa"),
                  ("Mahad","Frank"), ("Cyrille","Raissa"),("Cyrille","Victoire"),("Rose","Sirianne"),("Rose","Samson"),
                  ("Nadine","Abdul"),("Nadine","George"),("Samson","Rose"),("Samson","Josephine"), ("Agnes","Loyce"),
                  ("Agnes","George"), ("Mano","Donatien"),("Mano","George"),("Adrien","Caleb"),("Adrien","Mahad"),
                  ("Nasser","Frank"),("Nasser","Victoire"),("Jodelle","Rehema"),("Jodelle","Germaine"),("Sirianne","Dave"),
                  ("Sirianne","Rose"),("Caleb","Adrien"),("Caleb","Majeed"),("Richmond","Rehema"),("Richmond","Caleb"),
                  ("Germaine","Jodelle"),("Germaine","Hans"),("Younous","Romaric"),("Younous","Donatien"),("Victoire","Cyrille"),
                  ("Victoire","Younous"),("Ayao","Jodelle"),("Ayao","Younous"),("Patience","Blessing"),("Patience","Olusegun"),
                  ("Olusegun","Abdul"),("Olusegun","Patience"),("Romaric","Nasser"),("Romaric","Younous"),("Raissa","Cyrille"),
                  ("Raissa","Nadine"),("Majeed","Caleb"),("Majeed","Richmond"),("Loyce","Frank"),("Loyce","Josephine"),
                  ("Josephine","Loyce"),("Josephine","Blessing"),("Blessing","Patience"),("Blessing","Olusegun"),
                  ("Comfort","Blessing"),("Comfort","Abdul"),("George","Mano"),("George","Hans"),("Seun","Abdul"),
                  ("Seun","Rose"),("Rodrigue","Rose"),("Rogrigue","Hans"),("Nehemie","Janvier"),("Nehemie","Loyce"),
                  ("Rehema","Jodelle"),("Rehema","Richmond"),("Opeyemi","Rehema"),("Opeyemi","Sirianne"),("Frank","Rose"),
                  ("Frank","Romaric"),("Dave","Nadine"),("Dave","Christian"),("Donatien","Mano"),("Donatien","Richmond"),
                  ("Janvier","Mano"),("Janvier","George"),("Christian","Rose"),("Christian","Nehemie"),("Jafar","Mahad"),
                  ("Jafar","Roaa"),("Hans","Sirianne"),("Hans","Mano"),("Abdul","Nadine"),("Abdul","Comfort"),
                  ("Laura","Cyrille"), ("Laura","Raissa")])

# %%
Y=([("Baurice","Raissa"), ("Baurice","Adrien"), ("Roaa","Mahad"),("Roaa","Frank"),("Mahad","Roaa"),
                  ("Mahad","Frank"), ("Cyrille","Raissa"),("Cyrille","Victoire"),("Rose","Sirianne"),("Rose","Samson"),
                  ("Nadine","Abdul"),("Nadine","George"),("Samson","Rose"),("Samson","Josephine"), ("Agnes","Loyce"),
                  ("Agnes","George"), ("Mano","Donatien"),("Mano","George"),("Adrien","Caleb"),("Adrien","Mahad"),
                  ("Nasser","Frank"),("Nasser","Victoire"),("Jodelle","Rehema"),("Jodelle","Germaine"),("Sirianne","Dave"),
                  ("Sirianne","Rose"),("Caleb","Adrien"),("Caleb","Majeed"),("Richmond","Rehema"),("Richmond","Caleb"),
                  ("Germaine","Jodelle"),("Germaine","Hans"),("Younous","Romaric"),("Younous","Donatien"),("Victoire","Cyrille"),
                  ("Victoire","Younous"),("Ayao","Jodelle"),("Ayao","Younous"),("Patience","Blessing"),("Patience","Olusegun"),
                  ("Olusegun","Abdul"),("Olusegun","Patience"),("Romaric","Nasser"),("Romaric","Younous"),("Raissa","Cyrille"),
                  ("Raissa","Nadine"),("Majeed","Caleb"),("Majeed","Richmond"),("Loyce","Frank"),("Loyce","Josephine"),
                  ("Josephine","Loyce"),("Josephine","Blessing"),("Blessing","Patience"),("Blessing","Olusegun"),
                  ("Comfort","Blessing"),("Comfort","Abdul"),("George","Mano"),("George","Hans"),("Seun","Abdul"),
                  ("Seun","Rose"),("Rodrigue","Rose"),("Rogrigue","Hans"),("Nehemie","Janvier"),("Nehemie","Loyce"),
                  ("Rehema","Jodelle"),("Rehema","Richmond"),("Opeyemi","Rehema"),("Opeyemi","Sirianne"),("Frank","Rose"),
                  ("Frank","Romaric"),("Dave","Nadine"),("Dave","Christian"),("Donatien","Mano"),("Donatien","Richmond"),
                  ("Janvier","Mano"),("Janvier","George"),("Christian","Rose"),("Christian","Nehemie"),("Jafar","Mahad"),
                  ("Jafar","Roaa"),("Hans","Sirianne"),("Hans","Mano"),("Abdul","Nadine"),("Abdul","Comfort"),
                  ("Laura","Cyrille"), ("Laura","Raissa")


])

# %%
G.add_edges_from(Y)

# %%
G.number_of_edges()
# Out:
# 68

# %%
G.number_of_nodes()
# Out:
# 44

# %%
#pos = nx.spring_layout(G, scale=15)
pos = nx.spring_layout(G, k=0.9,iterations=20)
nx.draw(G, pos, with_labels=True, node_size=1050)

# %%
nx.draw(G, pos, with_labels=True, node_size=1050)
plt.savefig("path.png")

# %%
nx.write_pajek(G,"Aimslink.net")

# %%
G.degree("Frank")
# Out:
# 6

# %%
G.degree("Rose")
# Out:
# 6

# %%
G.degree(H)
# Out:
# DegreeView({'Baurice': 2, 'Roaa': 3, 'Mahad': 4, 'Cyrille': 3, 'Rose': 6, 'Nadine': 4, 'Samson': 2, 'Agnes': 2, 'Mano': 4, 'Adrien': 3, 'Nasser': 3, 'Jodelle': 3, 'Sirianne': 4, 'Caleb': 3, 'Richmond': 4, 'Germaine': 2, 'Younous': 4, 'Victoire': 3, 'Ayao': 2, 'Patience': 2, 'Olusegun': 3, 'Romaric': 3, 'Raissa': 4, 'Majeed': 2, 'Loyce': 4, 'Josephine': 3, 'Blessing': 4, 'Comfort': 2, 'George': 5, 'Seun': 2, 'Rodrigue': 1, 'Rehema': 3, 'Opeyemi': 2, 'Frank': 6, 'Dave': 3, 'Donatien': 3, 'Janvier': 3, 'Christian': 3, 'Jafar': 2, 'Hans': 5, 'Abdul': 4, 'Laura': 2, 'Nehemie': 3})

# %%
options = {
    'node_color': 'black',
    'node_size': 100,
    'width': 2,
}
nx.draw(G, with_labels=True, font_weight="bold")

# %%
G = nx.Graph()
G.add_nodes_from(["Baurice","Roaa","Mahad","Cyrille","Rose","Nadine","Samson","Agnes","Mano","Adrien","Nasser","Jodelle",
                  "Sirianne","Caleb","Richmond","Germaine","Younous","Victoire","Ayao","Patience","Olusegun","Romaric",
                  "Raissa","Majeed","Loyce","Josephine","Blessing","Comfort","George","Seun","Rodrigue","Rehema",
                  "Opeyemi","Frank","Dave","Donatien","Janvier","Christian","Jafar","Hans", "Abdul","Laura","Nehemie"])
G.add_edges_from([("Baurice","Raissa"), ("Baurice","Adrien"), ("Roaa","Mahad"),("Roaa","Frank"),("Mahad","Roaa"),
                  ("Mahad","Frank"), ("Cyrille","Raissa"),("Cyrille","Victoire"),("Rose","Sirianne"),("Rose","Samson"),
                  ("Nadine","Abdul"),("Nadine","George"),("Samson","Rose"),("Samson","Josephine"), ("Agnes","Loyce"),
                  ("Agnes","George"), ("Mano","Donatien"),("Mano","George"),("Adrien","Caleb"),("Adrien","Mahad"),
                  ("Nasser","Frank"),("Nasser","Victoire"),("Jodelle","Rehema"),("Jodelle","Germaine"),("Sirianne","Dave"),
                  ("Sirianne","Rose"),("Caleb","Adrien"),("Caleb","Majeed"),("Richmond","Rehema"),("Richmond","Caleb"),
                  ("Germaine","Jodelle"),("Germaine","Hans"),("Younous","Romaric"),("Younous","Donatien"),("Victoire","Cyrille"),
                  ("Victoire","Younous"),("Ayao","Jodelle"),("Ayao","Younous"),("Patience","Blessing"),("Patience","Olusegun"),
                  ("Olusegun","Abdul"),("Olusegun","Patience"),("Romaric","Nasser"),("Romaric","Younous"),("Raissa","Cyrille"),
                  ("Raissa","Nadine"),("Majeed","Caleb"),("Majeed","Richmond"),("Loyce","Frank"),("Loyce","Josephine"),
                  ("Josephine","Loyce"),("Josephine","Blessing"),("Blessing","Patience"),("Blessing","Olusegun"),
                  ("Comfort","Blessing"),("Comfort","Abdul"),("George","Mano"),("George","Hans"),("Seun","Abdul"),
                  ("Seun","Rose"),("Rodrigue","Rose"),("Rogrigue","Hans"),("Nehemie","Janvier"),("Nehemie","Loyce"),
                  ("Rehema","Jodelle"),("Rehema","Richmond"),("Opeyemi","Rehema"),("Opeyemi","Sirianne"),("Frank","Rose"),
                  ("Frank","Romaric"),("Dave","Nadine"),("Dave","Christian"),("Donatien","Mano"),("Donatien","Richmond"),
                  ("Janvier","Mano"),("Janvier","George"),("Christian","Rose"),("Christian","Nehemie"),("Jafar","Mahad"),
                  ("Jafar","Roaa"),("Hans","Sirianne"),("Hans","Mano"),("Abdul","Nadine"),("Abdul","Comfort"),
                  ("Laura","Cyrille"), ("Laura","Raissa")


])

nx.draw(G, with_labels=True, font_weight="bold")

# %%
nx.degree_centrality(G)
# Out:
# {'Baurice': 0.046511627906976744,
#  'Roaa': 0.06976744186046512,
#  'Mahad': 0.09302325581395349,
#  'Cyrille': 0.06976744186046512,
#  'Rose': 0.13953488372093023,
#  'Nadine': 0.09302325581395349,
#  'Samson': 0.046511627906976744,
#  'Agnes': 0.046511627906976744,
#  'Mano': 0.09302325581395349,
#  'Adrien': 0.06976744186046512,
#  'Nasser': 0.06976744186046512,
#  'Jodelle': 0.06976744186046512,
#  'Sirianne': 0.09302325581395349,
#  'Caleb': 0.06976744186046512,
#  'Richmond': 0.09302325581395349,
#  'Germaine': 0.046511627906976744,
#  'Younous': 0.09302325581395349,
#  'Victoire': 0.06976744186046512,
#  'Ayao': 0.046511627906976744,
#  'Patience': 0.046511627906976744,
#  'Olusegun': 0.06976744186046512,
#  'Romaric': 0.06976744186046512,
#  'Raissa': 0.09302325581395349,
#  'Majeed': 0.046511627906976744,
#  'Loyce': 0.09302325581395349,
#  'Josephine': 0.06976744186046512,
#  'Blessing': 0.09302325581395349,
#  'Comfort': 0.046511627906976744,
# ...

# %%
c=nx.clustering(G)

# %%
c
# Out:
# {'Baurice': 0,
#  'Roaa': 0.6666666666666666,
#  'Mahad': 0.3333333333333333,
#  'Cyrille': 0.3333333333333333,
#  'Rose': 0,
#  'Nadine': 0,
#  'Samson': 0,
#  'Agnes': 0,
#  'Mano': 0.3333333333333333,
#  'Adrien': 0,
#  'Nasser': 0.3333333333333333,
#  'Jodelle': 0,
#  'Sirianne': 0,
#  'Caleb': 0.3333333333333333,
#  'Richmond': 0.16666666666666666,
#  'Germaine': 0,
#  'Younous': 0,
#  'Victoire': 0,
#  'Ayao': 0,
#  'Patience': 1.0,
#  'Olusegun': 0.3333333333333333,
#  'Romaric': 0.3333333333333333,
#  'Raissa': 0.16666666666666666,
#  'Majeed': 1.0,
#  'Loyce': 0,
#  'Josephine': 0,
#  'Blessing': 0.16666666666666666,
#  'Comfort': 0,
#  'George': 0.2,
#  'Seun': 0,
#  'Rodrigue': 0,
#  'Rehema': 0,
#  'Opeyemi': 0,
#  'Frank': 0.13333333333333333,
#  'Dave': 0,
#  'Donatien': 0,
#  'Janvier': 0.3333333333333333,
#  'Christian': 0,
#  'Jafar': 1.0,
#  'Hans': 0.1,
#  'Abdul': 0,
#  'Laura': 1.0,
#  'Nehemie': 0,
#  'Rogrigue': 0}
